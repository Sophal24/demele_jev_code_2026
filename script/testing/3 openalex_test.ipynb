# %%
import requests
import pandas as pd
from requests.auth import HTTPBasicAuth

# %%
# https://odkcentral2025.uhs.edu.kh/v1/projects/1/forms/A1_Questionnaire_Cohort1_Baseline.svc

# https://api.openalex.org/works

# %%
import requests

url = "https://api.openalex.org/works?search.title_and_abstract=Antimicrobial+Resistance&sort=relevance_score%3Adesc"


response = requests.get(url)

data = response.json()

data
# Out:
# {'meta': {'count': 180469,
#   'db_response_time_ms': 64,
#   'page': 1,
#   'per_page': 25,
#   'groups_count': None,
#   'cost_usd': 0.001},
#  'results': [{'id': 'https://openalex.org/W4206677002',
#    'doi': 'https://doi.org/10.1016/s0140-6736(21)02724-0',
#    'title': 'Global burden of bacterial antimicrobial resistance in 2019: a systematic analysis',
#    'display_name': 'Global burden of bacterial antimicrobial resistance in 2019: a systematic analysis',
#    'relevance_score': 5067.716,
#    'publication_year': 2022,
#    'publication_date': '2022-01-19',
#    'ids': {'openalex': 'https://openalex.org/W4206677002',
#     'doi': 'https://doi.org/10.1016/s0140-6736(21)02724-0',
#     'pmid': 'https://pubmed.ncbi.nlm.nih.gov/35065702'},
#    'language': 'en',
#    'primary_location': {'id': 'doi:10.1016/s0140-6736(21)02724-0',
#     'is_oa': True,
#     'landing_page_url': 'https://doi.org/10.1016/s0140-6736(21)02724-0',
# ...

# %%
data.keys()
# Out:
# dict_keys(['meta', 'results', 'group_by'])

# %%
data['meta']
# Out:
# {'count': 180469,
#  'db_response_time_ms': 64,
#  'page': 1,
#  'per_page': 25,
#  'groups_count': None,
#  'cost_usd': 0.001}

# %%
data['results'][1]
# Out:
# {'id': 'https://openalex.org/W2134852597',
#  'doi': 'https://doi.org/10.1093/jac/dks261',
#  'title': 'Identification of acquired antimicrobial resistance genes',
#  'display_name': 'Identification of acquired antimicrobial resistance genes',
#  'relevance_score': 3832.482,
#  'publication_year': 2012,
#  'publication_date': '2012-07-10',
#  'ids': {'openalex': 'https://openalex.org/W2134852597',
#   'doi': 'https://doi.org/10.1093/jac/dks261',
#   'mag': '2134852597',
#   'pmid': 'https://pubmed.ncbi.nlm.nih.gov/22782487'},
#  'language': 'en',
#  'primary_location': {'id': 'doi:10.1093/jac/dks261',
#   'is_oa': True,
#   'landing_page_url': 'https://doi.org/10.1093/jac/dks261',
#   'pdf_url': 'https://academic.oup.com/jac/article-pdf/67/11/2640/2085909/dks261.pdf',
#   'source': {'id': 'https://openalex.org/S124275759',
#    'display_name': 'Journal of Antimicrobial Chemotherapy',
#    'issn_l': '0305-7453',
#    'issn': ['0305-7453', '1460-2091'],
#    'is_oa': False,
# ...

# %%
data['results'][0]
# Out:
# {'id': 'https://openalex.org/W4206677002',
#  'doi': 'https://doi.org/10.1016/s0140-6736(21)02724-0',
#  'title': 'Global burden of bacterial antimicrobial resistance in 2019: a systematic analysis',
#  'display_name': 'Global burden of bacterial antimicrobial resistance in 2019: a systematic analysis',
#  'relevance_score': 5067.716,
#  'publication_year': 2022,
#  'publication_date': '2022-01-19',
#  'ids': {'openalex': 'https://openalex.org/W4206677002',
#   'doi': 'https://doi.org/10.1016/s0140-6736(21)02724-0',
#   'pmid': 'https://pubmed.ncbi.nlm.nih.gov/35065702'},
#  'language': 'en',
#  'primary_location': {'id': 'doi:10.1016/s0140-6736(21)02724-0',
#   'is_oa': True,
#   'landing_page_url': 'https://doi.org/10.1016/s0140-6736(21)02724-0',
#   'pdf_url': 'http://www.thelancet.com/article/S0140673621027240/pdf',
#   'source': {'id': 'https://openalex.org/S49861241',
#    'display_name': 'The Lancet',
#    'issn_l': '0140-6736',
#    'issn': ['0140-6736', '1474-547X'],
# ...
