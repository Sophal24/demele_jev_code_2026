# %%
import requests
import pandas as pd
from io import StringIO

# use v3

# %%
url = "https://demele-jev.uhs.edu.kh/api/download-submissions-v3?formId=A1_Questionnaire_Cohort1_Baseline&secret_key=13ac3c2f-b7df-4ce9-8010-247da09a91d9"

response = requests.get(url)

# Convert bytes → string → DataFrame
df = pd.read_csv(StringIO(response.text))

# %%
df.head(5)
# Out:
#              SubmissionDate         I1d                            I2s  \
# 0  2026-04-29T04:31:01.811Z  2026-04-29  2026-04-29T10:43:04.671+07:00
# 1  2026-04-29T04:24:19.921Z  2026-04-29  2026-04-29T11:17:30.703+07:00
# 2  2026-04-29T04:10:15.209Z  2026-04-29  2026-04-29T11:09:22.229+07:00
# 3  2026-04-29T03:37:55.478Z  2026-04-29  2026-04-29T10:30:29.093+07:00
# 4  2026-04-29T03:21:55.237Z  2026-04-29  2026-04-29T10:14:59.051+07:00
#
#                              I3e                       I4d  I5u        g_A-A1  \
# 0  2026-04-29T11:31:00.918+07:00  collect:9qMhME16PHTSvgub  T02  DEM1-PP-0464
# 1  2026-04-29T11:24:19.231+07:00  collect:HWmr5IpdBFgGHeiN  T03  DEM1-SR-0316
# 2  2026-04-29T11:10:14.692+07:00  collect:RQ1eyOTTgb72DTff  T12  DEM1-SR-0316
# 3  2026-04-29T10:37:54.889+07:00  collect:HWmr5IpdBFgGHeiN  T03  DEM1-SR-0312
# 4  2026-04-29T10:21:54.651+07:00  collect:HWmr5IpdBFgGHeiN  T03  DEM1-SR-0311
#
#   g_A-g_A1m-A1manual g_A-g_A1m-A1m_s  g_A-g_A1m-A1m_cal  ...  \
# ...

# %%
df.shape
# Out:
# (1623, 481)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1623 entries, 0 to 1622
# Columns: 481 entries, SubmissionDate to FormVersion
# dtypes: float64(347), int64(4), object(130)
# memory usage: 6.0+ MB
