# %%
import pandas as pd
import os

# %%
a1_questionnaire_cohort1_baseline = ""
a2_questionnaire_cohort1_y1 = ""
a3_questionnaire_cohort1_y2 = ""

a4_questionnaire_cohort2_baseline = "../../dataset/data_combination/A4_Questionnaire_Cohort2_Baseline.csv"
a5_questionnaire_cohort2_m1 = ""
a6_questionnaire_cohort2_m3 = ""
a7_questionnaire_cohort2_m6 = ""
a8_questionnaire_cohort2_y1 = ""

b1_sample_collection_form_cohort1_baseline = ""
b2_sample_collection_form_cohort1_y1 = ""
b3_sample_collection_form_cohort1_y2 = ""

b4_sample_collection_form_cohort2_baseline = "../../dataset/data_combination/B4_Sample_Collection_Form_Cohort2_Baseline.csv"
b5_sample_collection_form_cohort2_m1 = "../../dataset/data_combination/"
b6_sample_collection_form_cohort2_m3 = "../../dataset/data_combination/"
b7_sample_collection_form_cohort2_m6 = "../../dataset/data_combination/"
b8_sample_collection_form_cohort2_y1 = "../../dataset/data_combination/"

c1_lab_result_cohort1_baseline_elisa = ""
c2_lab_result_cohort1_y1_elisa = ""
c3_lab_result_cohort1_y2_elisa = ""

c4_lab_result_cohort2_baseline_elisa = "../../dataset/data_combination/B4_Sample_Collection_Form_Cohort2_Baseline.csv"
c5_lab_result_cohort2_baseline_qiastat_pcr = "../../dataset/data_combination/C5_LabResult_Cohort2_Baseline_QIASTAT_PCR.csv"
c6_lab_result_cohort2_baseline_ipc_genxpert = "../../dataset/data_combination/"
c7_lab_result_cohort2_baseline_ipc_tb_culture = "../../dataset/data_combination/"
c8_lab_result_cohort2_m1_elisa = "../../dataset/data_combination/"

c9a_lab_result_pdf_ipc_genxpert = ""
c9b_lab_result_pdf_ipc_tb_culture = ""

d1_screening_form_cohort1_baseline = ""
d2_screening_form_cohort1_y1 = ""
d3_screening_form_cohort1_y2 = ""

d4_screening_form_cohort2_baseline = "../../dataset/data_combination/C4_LabResult_Cohort2_Baseline_ELISA.csv"
d5_screening_form_cohort2_m1 = ""
d6_screening_form_cohort2_m3 = ""
d7_screening_form_cohort2_m6 = ""
d8_screening_form_cohort2_y1 = ""

# %%
d4_df = pd.read_csv(d4_screening_form_cohort2_baseline)

a4_df = pd.read_csv(a4_questionnaire_cohort2_baseline) # exclude for now
b4_df = pd.read_csv(b4_sample_collection_form_cohort2_baseline)
c4_df = pd.read_csv(c4_lab_result_cohort2_baseline_elisa)
c5_df = pd.read_csv(c5_lab_result_cohort2_baseline_qiastat_pcr)

# %%
d4_df.head(5)
# Out:
#              SubmissionDate         I1d                            I2s  \
# 0  2026-06-16T01:13:09.333Z  2026-06-16  2026-06-16T08:09:38.497+07:00
# 1  2026-06-16T01:09:20.798Z  2026-06-16  2026-06-16T08:04:56.626+07:00
# 2  2026-06-16T01:04:37.971Z  2026-06-16  2026-06-16T08:01:04.460+07:00
# 1    2026-06-16T01:13:09.333Z  2026-06-16  2026-06-16T08:09:38.497+07:00
# 2    2026-06-16T01:09:20.798Z  2026-06-16  2026-06-16T08:04:56.626+07:00
# 3    2026-06-16T01:04:37.971Z  2026-06-16  2026-06-16T08:01:04.460+07:00
# 4    2026-06-16T00:51:34.675Z  2026-06-16  2026-06-16T07:48:12.641+07:00
# ..                        ...         ...                            ...
# 519  2025-12-28T02:31:27.399Z  2025-12-27  2025-12-27T23:00:19.975+07:00
# 520  2025-12-28T02:29:43.175Z  2025-12-23  2025-12-23T11:20:05.083+07:00
# 521  2025-12-28T02:29:43.175Z  2025-12-23  2025-12-23T11:20:05.083+07:00
# 522  2025-12-28T02:29:32.572Z  2025-12-23  2025-12-23T10:43:02.770+07:00
# 523  2025-12-28T02:29:32.572Z  2025-12-23  2025-12-23T10:43:02.770+07:00
#
#                              I3e_x                     I4d_x I5u_x  \
# ...

# %%
merged_df = pd.merge(merged_df, b4_df, on="A1", how="left")
merged_df
# Out:
#              SubmissionDate_x       I1d_x                          I2s_x  \
# 0    2026-06-16T01:13:09.333Z  2026-06-16  2026-06-16T08:09:38.497+07:00
# 1    2026-06-16T01:13:09.333Z  2026-06-16  2026-06-16T08:09:38.497+07:00
# 2    2026-06-16T01:09:20.798Z  2026-06-16  2026-06-16T08:04:56.626+07:00
# 3    2026-06-16T01:04:37.971Z  2026-06-16  2026-06-16T08:01:04.460+07:00
# 4    2026-06-16T00:51:34.675Z  2026-06-16  2026-06-16T07:48:12.641+07:00
# ..                        ...         ...                            ...
# 525  2025-12-28T02:31:27.399Z  2025-12-27  2025-12-27T23:00:19.975+07:00
# 526  2025-12-28T02:29:43.175Z  2025-12-23  2025-12-23T11:20:05.083+07:00
# 527  2025-12-28T02:29:43.175Z  2025-12-23  2025-12-23T11:20:05.083+07:00
# 528  2025-12-28T02:29:32.572Z  2025-12-23  2025-12-23T10:43:02.770+07:00
# 529  2025-12-28T02:29:32.572Z  2025-12-23  2025-12-23T10:43:02.770+07:00
#
#                              I3e_x                     I4d_x I5u_x  \
# ...

# %%
_x = 0 
_y = 0
for col in merged_df.columns:
    # print(col)
    if col.endswith('_x'):
        print(col)
        _x += 1
    if col.endswith('_y'):
        print(col)
        _y += 1

print(_x, _y)
# Out:
# SubmissionDate_x
# I1d_x
# I2s_x
# I3e_x
# I4d_x
# I5u_x
# A1manual_x
# A1m_s_x
# A1m_cal_x
# n_A1m_x
# A2_x
# A3_x
# A6_x
# A7_x
# A4_x
# A5_x
# D1_x
# instanceID_x
# instanceName_x
# KEY_x
# SubmitterID_x
# SubmitterName_x
# AttachmentsPresent_x
# AttachmentsExpected_x
# Status_x
# ReviewState_x
# DeviceID_x
# Edits_x
# FormVersion_x
# SubmissionDate_y
# I1d_y
# I2s_y
# I3e_y
# I4d_y
# I5u_y
# A1manual_y
# A1m_s_y
# A1m_cal_y
# n_A1m_y
# A2_y
# A3_y
# A4_y
# A5_y
# A6_y
# A7_y
# B1_x
# B2_x
# B3_x
# B4_x
# B5_x
# C2_x
# C3_x
# C4_x
# C5_x
# instanceID_y
# instanceName_y
# KEY_y
# SubmitterID_y
# SubmitterName_y
# AttachmentsPresent_y
# AttachmentsExpected_y
# Status_y
# ReviewState_y
# DeviceID_y
# Edits_y
# FormVersion_y
# B1_y
# B2_y
# B3_y
# B4_y
# B5_y
# C2_y
# C3_y
# C4_y
# C5_y
# D1_y
# 38 38

# %%
merged_df = merged_df.loc[
    :,
    ~merged_df.columns.str.endswith('_x')
]

# %%
merged_df = pd.merge(merged_df, c4_df, on="A1", how="left")
merged_df = merged_df.loc[
    :,
    ~merged_df.columns.str.endswith('_x')
]
merged_df
# Out:
#                A1  A6/1  A6/2             A8   A9                 A10  \
# 0    DEM2-SR-0042     1     1  SEN SOPHOASH   2.0    TEK CHHEAVKOSAL
# 1    DEM2-SR-0042     1     1  SEN SOPHOASH   2.0    TEK CHHEAVKOSAL
# 2    DEM2-SR-0041     1     1  CHHIT SAMOUN   2.0         Dr.SEM RAVY
# 3    DEM2-SR-0040     1     1     TY SOTHEA   2.0    Dr.NGY MENGHONG
# 4    DEM2-SR-0039     1     1  CHHIT SAMOUN   2.0         Dr.SEM RAVY
# ..            ...   ...   ...            ...  ...                 ...
# 537  DEM2-PP-0009     1     1   Mai sreyneth  2.0  Dr Nuon Neathvibol
# 538           NaN     1     1         DAVANN  2.0       Dr CHAN MARDY
# 539           NaN     1     1         DAVANN  2.0       Dr CHAN MARDY
# 540           NaN     1     1              V  2.0         Dr Meng Lun
# 541           NaN     1     1              V  2.0         Dr Meng Lun
#
#                   A11         A1_id        A1_1                A1_2  ...  \
# ...

# %%
merged_df = pd.merge(merged_df, c5_df, on="A1", how="left")
merged_df
# Out:
#                A1  A6/1_x  A6/2_x           A8_x  A9_x             A10_x  \
# 0    DEM2-SR-0042       1       1  SEN SOPHOASH    2.0  TEK CHHEAVKOSAL
# 1    DEM2-SR-0042       1       1  SEN SOPHOASH    2.0  TEK CHHEAVKOSAL
# 2    DEM2-SR-0041       1       1  CHHIT SAMOUN    2.0       Dr.SEM RAVY
# 3    DEM2-SR-0040       1       1     TY SOTHEA    2.0  Dr.NGY MENGHONG
# 4    DEM2-SR-0039       1       1  CHHIT SAMOUN    2.0       Dr.SEM RAVY
# ..            ...     ...     ...            ...   ...               ...
# 629           NaN       1       1              V   2.0       Dr Meng Lun
# 630           NaN       1       1              V   2.0       Dr Meng Lun
# 631           NaN       1       1              V   2.0       Dr Meng Lun
# 632           NaN       1       1              V   2.0       Dr Meng Lun
# 633           NaN       1       1              V   2.0       Dr Meng Lun
#
#                 A11_x       A1_id_x      A1_1_x              A1_2_x  ...  \
# ...
